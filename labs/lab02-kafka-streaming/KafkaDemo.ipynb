# %% [markdown]
# # Kafka Demo
#
# ### Connect to Kafka Broker Server
# ```
# ssh -o ServerAliveInterval=60 -L 9092:localhost:9092 tunnel@128.2.204.215 -NTf
# ```
# pass: seaitunnel
#
#
# To kill connection at port:
# ```
# lsof -ti:9092 | xargs kill -9
# ```
#
# ### Setup
# ```
# python -m pip install kafka-python
# ```

# %%
from os import path
import sys, os
from datetime import datetime
from json import dumps, loads
from time import sleep
from random import randint
import numpy as np
# ssh -o ServerAliveInterval=60 -L 9092:localhost:9092 tunnel@128.2.24.106 -NTf
from kafka import KafkaConsumer, KafkaProducer

# Update this for your own recitation section :)
topic = 'recitation-d'

# %% [markdown]
# ### Producer Mode -> Writes Data to Broker

# %%
# Create a producer to write data to kafka
# Ref: https://kafka-python.readthedocs.io/en/master/apidoc/KafkaProducer.html

# [TODO]: Replace '...' with the address of your Kafka bootstrap server
producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                        value_serializer=lambda x: dumps(x).encode('utf-8'),
                        )

# [TODO]: Add cities of your choice
cities = ['Toronto', 'Fuzhou', 'Guangzhou']

# Write data via the producer
print("Writing to Kafka Broker")
for i in range(10):
    data = f'{datetime.now().strftime("%Y-%m-%d %H:%M:%S")},{cities[randint(0,len(cities)-1)]},{randint(18, 32)}ºC'
    print(f"Writing: {data}")
    producer.send(topic = 'weather-wujinho1', value=data)
    sleep(1)
# Out:
# Writing to Kafka Broker
# Writing: 2026-02-16 20:14:11,Guangzhou,27ºC
# Writing: 2026-02-16 20:14:13,Toronto,23ºC
# Writing: 2026-02-16 20:14:14,Fuzhou,26ºC
# Writing: 2026-02-16 20:14:15,Guangzhou,27ºC
# Writing: 2026-02-16 20:14:16,Guangzhou,19ºC
# Writing: 2026-02-16 20:14:17,Guangzhou,30ºC
# Writing: 2026-02-16 20:14:18,Fuzhou,20ºC
# Writing: 2026-02-16 20:14:19,Fuzhou,29ºC
# Writing: 2026-02-16 20:14:20,Guangzhou,24ºC
# Writing: 2026-02-16 20:14:21,Guangzhou,24ºC

# %% [markdown]
# ### Consumer Mode -> Reads Data from Broker

# %%
# Create a consumer to read data from kafka
# Ref: https://kafka-python.readthedocs.io/en/master/apidoc/KafkaConsumer.html

# [TODO]: Complete the missing ... parameters/arguments using the Kafka documentation
consumer = KafkaConsumer(
    'weather-wujinho1',  # <- Your topic name
    bootstrap_servers=['localhost:9092'],  # <- Your Kafka server
    auto_offset_reset='earliest', #Experiment with different values
    # Commit that an offset has been read
    enable_auto_commit=True,
    # How often to tell Kafka, an offset has been read
    auto_commit_interval_ms=1000
)
print('Reading Kafka Broker')
for message in consumer:

    message = message.value.decode()
    # Default message.value type is bytes!
    print(loads(message))
    os.system(f"echo {message} >> kafka_log.csv")
# Out:
# Reading Kafka Broker
# 2026-02-16 20:14:11,Guangzhou,27ºC
# 2026-02-16 20:14:13,Toronto,23ºC
# 2026-02-16 20:14:14,Fuzhou,26ºC
# 2026-02-16 20:14:15,Guangzhou,27ºC
# 2026-02-16 20:14:16,Guangzhou,19ºC
# 2026-02-16 20:14:17,Guangzhou,30ºC
# 2026-02-16 20:14:18,Fuzhou,20ºC
# 2026-02-16 20:14:19,Fuzhou,29ºC
# 2026-02-16 20:14:20,Guangzhou,24ºC
# 2026-02-16 20:14:21,Guangzhou,24ºC
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 15
#       5 consumer = KafkaConsumer(
#       6     'weather-wujinho1',  # <- Your topic name
#       7     bootstrap_servers=['localhost:9092'],  # <- Your Kafka server
#    (...)     12     auto_commit_interval_ms=1000
#      13 )
#      14 print('Reading Kafka Broker')
# ---> 15 for message in consumer:
#      17     message = message.value.decode()
#      18     # Default message.value type is bytes!
#
# File ~/mlip-kafka-lab/venv/lib/python3.12/site-packages/kafka/consumer/group.py:1213, in KafkaConsumer.__next__(self)
#    1211     self._iterator = self._message_generator_v2()
#    1212 try:
# -> 1213     return next(self._iterator)
#    1214 except StopIteration:
#    1215     self._iterator = None
#
# File ~/mlip-kafka-lab/venv/lib/python3.12/site-packages/kafka/consumer/group.py:1185, in KafkaConsumer._message_generator_v2(self)
#    1183 def _message_generator_v2(self):
#    1184     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1185     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1186     for tp, records in six.iteritems(record_map):
#    1187         # Generators are stateful, and it is possible that the tp / records
#    1188         # here may become stale during iteration -- i.e., we seek to a
#    1189         # different offset, pause consumption, or lose assignment.
#    1190         for record in records:
#    1191             # is_fetchable(tp) should handle assignment changes and offset
#    1192             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1193             # outer function destroying the existing iterator/generator
#    1194             # via self._iterator = None
#
# File ~/mlip-kafka-lab/venv/lib/python3.12/site-packages/kafka/consumer/group.py:708, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     706 timer = Timer(timeout_ms)
#     707 while not self._closed:
# --> 708     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     709     if records:
#     710         return records
#
# File ~/mlip-kafka-lab/venv/lib/python3.12/site-packages/kafka/consumer/group.py:757, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     754     log.debug('poll: do not have all fetch positions...')
#     755     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 757 self._client.poll(timeout_ms=poll_timeout_ms)
#     758 # after the long poll, we should check whether the group needs to rebalance
#     759 # prior to returning data so that the group can stabilize faster
#     760 if self._coordinator.need_rejoin():
#
# File ~/mlip-kafka-lab/venv/lib/python3.12/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File ~/mlip-kafka-lab/venv/lib/python3.12/site-packages/kafka/client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File /usr/lib/python3.12/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# # Use kcat!
# It's a CLI (Command Line Interface). Previously known as kafkacat
#
#
# Ref: https://docs.confluent.io/platform/current/app-development/kafkacat-usage.html

# %%
#kcat command: connect to local Kafka broker, specify a topic, and consume messages from the earliest offset
